# %% [markdown]
# ### Cào urls của tất cả các jobs

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# Cấu hình Selenium và đường dẫn ChromeDriver
CHROMEDRIVER_PATH = "D:\\Downloads\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"  # Thay bằng đường dẫn ChromeDriver (Windows)


# Hàm lấy liên kết công việc từ một trang
def fetch_job_links_from_page_selenium(base_url, page):
    url = f"{base_url}tat-ca-viec-lam-trang-{page}-vi.html"
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Chạy không giao diện
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")

    # Sử dụng Service với ChromeDriver có sẵn
    service = Service(CHROMEDRIVER_PATH)
    driver = webdriver.Chrome(service=service, options=chrome_options)
    driver.get(url)
    time.sleep(5)  # Đợi cho trang tải xong

    job_links_list = []
    job_links = driver.find_elements(By.CSS_SELECTOR, 'h2 > .job_link')  # Sửa lại CSS selector cho đúng
    job_links_list = [job.get_attribute('href') for job in job_links]

    driver.quit()
    print(f"Lấy được {len(job_links_list)} liên kết công việc từ trang {page}")
    return job_links_list

# Sử dụng Selenium để cào tất cả các trang với đa luồng
def get_all_job_links_selenium_multithread(base_url, start_page=1, max_pages=10, max_workers=5):
    job_links = []
    pages = range(start_page, max_pages + 1)

    # Sử dụng ThreadPoolExecutor để cào đa luồng
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_page = {executor.submit(fetch_job_links_from_page_selenium, base_url, page): page for page in pages}
        for future in as_completed(future_to_page):
            page = future_to_page[future]
            try:
                result = future.result()
                if result:
                    job_links.extend(result)
            except Exception as e:
                print(f"Lỗi khi lấy liên kết từ trang {page}: {e}")

    return job_links

# Sử dụng ví dụ
if __name__ == "__main__":
    BASE_URL = "https://careerviet.vn/viec-lam/"
    job_links = get_all_job_links_selenium_multithread(BASE_URL, max_pages=505, max_workers=10)

    # Lưu liên kết vào tệp
    with open('job_links.txt', 'w', encoding='utf-8') as f:
        for link in job_links:
            f.write(link + '\n')
# Out:
# Lấy được 50 liên kết công việc từ trang 6
# Lấy được 50 liên kết công việc từ trang 1
# Lấy được 50 liên kết công việc từ trang 2
# Lấy được 50 liên kết công việc từ trang 7
# Lấy được 50 liên kết công việc từ trang 9
# Lấy được 50 liên kết công việc từ trang 4
# Lấy được 50 liên kết công việc từ trang 10
# Lấy được 50 liên kết công việc từ trang 8
# Lấy được 50 liên kết công việc từ trang 3
# Lấy được 50 liên kết công việc từ trang 5
# Lấy được 50 liên kết công việc từ trang 11
# Lấy được 0 liên kết công việc từ trang 15
# Lấy được 50 liên kết công việc từ trang 19
# Lấy được 50 liên kết công việc từ trang 16
# Lấy được 50 liên kết công việc từ trang 12
# Lấy được 50 liên kết công việc từ trang 14
# Lấy được 50 liên kết công việc từ trang 13
# Lấy được 50 liên kết công việc từ trang 20
# Lấy được 50 liên kết công việc từ trang 21
# Lấy được 50 liên kết công việc từ trang 18
# Lấy được 50 liên kết công việc từ trang 22
# Lấy được 50 liên kết công việc từ trang 17
# Lấy được 50 liên kết công việc từ trang 32
# Lấy được 50 liên kết công việc từ trang 27
# Lấy được 50 liên kết công việc từ trang 25
# Lấy được 50 liên kết công việc từ trang 28
# Lấy được 50 liên kết công việc từ trang 26
# Lấy được 50 liên kết công việc từ trang 29
# Lấy được 50 liên kết công việc từ trang 24
# Lấy được 50 liên kết công việc từ trang 30
# Lấy được 50 liên kết công việc từ trang 31
# Lấy được 50 liên kết công việc từ trang 33
# Lấy được 20 liên kết công việc từ trang 36
# Lấy được 50 liên kết công việc từ trang 34
# Lấy được 20 liên kết công việc từ trang 38
# Lấy được 50 liên kết công việc từ trang 35
# Lấy được 50 liên kết công việc từ trang 37
# Lấy được 50 liên kết công việc từ trang 40
# Lấy được 50 liên kết công việc từ trang 42
# Lấy được 50 liên kết công việc từ trang 39
# Lấy được 50 liên kết công việc từ trang 43
# Lấy được 50 liên kết công việc từ trang 41
# Lấy được 50 liên kết công việc từ trang 23
# Lấy được 50 liên kết công việc từ trang 44
# Lấy được 50 liên kết công việc từ trang 46
# Lấy được 50 liên kết công việc từ trang 45
# Lấy được 50 liên kết công việc từ trang 48
# Lấy được 50 liên kết công việc từ trang 49
# Lấy được 50 liên kết công việc từ trang 50
# Lấy được 50 liên kết công việc từ trang 53
# Lấy được 50 liên kết công việc từ trang 52
# Lấy được 50 liên kết công việc từ trang 55
# Lấy được 50 liên kết công việc từ trang 56
# Lấy được 50 liên kết công việc từ trang 54
# Lấy được 50 liên kết công việc từ trang 57
# Lấy được 50 liên kết công việc từ trang 51
# Lấy được 50 liên kết công việc từ trang 59
# Lấy được 50 liên kết công việc từ trang 63
# Lấy được 50 liên kết công việc từ trang 60
# Lấy được 50 liên kết công việc từ trang 61
# Lấy được 50 liên kết công việc từ trang 58
# Lấy được 50 liên kết công việc từ trang 64
# Lấy được 50 liên kết công việc từ trang 62
# Lấy được 50 liên kết công việc từ trang 65
# Lấy được 50 liên kết công việc từ trang 66
# Lấy được 20 liên kết công việc từ trang 67
# Lấy được 50 liên kết công việc từ trang 68
# Lấy được 50 liên kết công việc từ trang 73
# Lấy được 50 liên kết công việc từ trang 71
# Lấy được 50 liên kết công việc từ trang 70
# Lỗi khi lấy liên kết từ trang 47: HTTPConnectionPool(host='localhost', port=63090): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 74
# Lấy được 50 liên kết công việc từ trang 69
# Lấy được 50 liên kết công việc từ trang 75
# Lấy được 50 liên kết công việc từ trang 76
# Lấy được 50 liên kết công việc từ trang 72
# Lấy được 50 liên kết công việc từ trang 77
# Lấy được 50 liên kết công việc từ trang 78
# Lấy được 50 liên kết công việc từ trang 81
# Lấy được 50 liên kết công việc từ trang 82
# Lấy được 20 liên kết công việc từ trang 83
# Lấy được 20 liên kết công việc từ trang 84
# Lấy được 50 liên kết công việc từ trang 79
# Lấy được 50 liên kết công việc từ trang 80
# Lấy được 20 liên kết công việc từ trang 85
# Lấy được 50 liên kết công việc từ trang 86
# Lấy được 50 liên kết công việc từ trang 87
# Lấy được 50 liên kết công việc từ trang 88
# Lấy được 50 liên kết công việc từ trang 89
# Lấy được 50 liên kết công việc từ trang 91
# Lấy được 50 liên kết công việc từ trang 92
# Lấy được 50 liên kết công việc từ trang 93
# Lấy được 50 liên kết công việc từ trang 96
# Lấy được 50 liên kết công việc từ trang 95
# Lấy được 50 liên kết công việc từ trang 90
# Lấy được 50 liên kết công việc từ trang 94
# Lấy được 20 liên kết công việc từ trang 105
# Lấy được 50 liên kết công việc từ trang 98
# Lấy được 50 liên kết công việc từ trang 101
# Lấy được 50 liên kết công việc từ trang 104
# Lấy được 50 liên kết công việc từ trang 100
# Lấy được 50 liên kết công việc từ trang 106
# Lấy được 20 liên kết công việc từ trang 103
# Lấy được 50 liên kết công việc từ trang 102
# Lấy được 50 liên kết công việc từ trang 107
# Lấy được 50 liên kết công việc từ trang 109
# Lấy được 50 liên kết công việc từ trang 108
# Lấy được 50 liên kết công việc từ trang 110
# Lấy được 50 liên kết công việc từ trang 113
# Lấy được 50 liên kết công việc từ trang 112
# Lấy được 50 liên kết công việc từ trang 111
# Lấy được 50 liên kết công việc từ trang 99
# Lấy được 50 liên kết công việc từ trang 115
# Lấy được 20 liên kết công việc từ trang 114
# Lấy được 50 liên kết công việc từ trang 118
# Lấy được 50 liên kết công việc từ trang 120
# Lấy được 50 liên kết công việc từ trang 117
# Lấy được 50 liên kết công việc từ trang 123
# Lấy được 50 liên kết công việc từ trang 116
# Lấy được 50 liên kết công việc từ trang 122
# Lấy được 50 liên kết công việc từ trang 121
# Lấy được 50 liên kết công việc từ trang 124
# Lỗi khi lấy liên kết từ trang 97: HTTPConnectionPool(host='localhost', port=50858): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 119
# Lấy được 20 liên kết công việc từ trang 130
# Lấy được 50 liên kết công việc từ trang 128
# Lấy được 50 liên kết công việc từ trang 126
# Lấy được 50 liên kết công việc từ trang 132
# Lấy được 50 liên kết công việc từ trang 129
# Lấy được 50 liên kết công việc từ trang 125
# Lấy được 50 liên kết công việc từ trang 133
# Lấy được 50 liên kết công việc từ trang 127
# Lấy được 50 liên kết công việc từ trang 136
# Lấy được 50 liên kết công việc từ trang 135
# Lấy được 20 liên kết công việc từ trang 138
# Lấy được 50 liên kết công việc từ trang 141
# Lấy được 50 liên kết công việc từ trang 131
# Lấy được 50 liên kết công việc từ trang 142
# Lấy được 50 liên kết công việc từ trang 134
# Lấy được 50 liên kết công việc từ trang 139
# Lấy được 20 liên kết công việc từ trang 140
# Lấy được 50 liên kết công việc từ trang 144
# Lấy được 50 liên kết công việc từ trang 143
# Lấy được 50 liên kết công việc từ trang 146
# Lấy được 50 liên kết công việc từ trang 145
# Lấy được 50 liên kết công việc từ trang 147
# Lấy được 20 liên kết công việc từ trang 150
# Lấy được 50 liên kết công việc từ trang 152
# Lấy được 50 liên kết công việc từ trang 154
# Lấy được 50 liên kết công việc từ trang 149
# Lấy được 50 liên kết công việc từ trang 151
# Lấy được 50 liên kết công việc từ trang 155
# Lấy được 50 liên kết công việc từ trang 156
# Lấy được 50 liên kết công việc từ trang 153
# Lấy được 50 liên kết công việc từ trang 157
# Lấy được 50 liên kết công việc từ trang 161
# Lấy được 20 liên kết công việc từ trang 159
# Lấy được 50 liên kết công việc từ trang 160
# Lấy được 50 liên kết công việc từ trang 162
# Lấy được 50 liên kết công việc từ trang 148
# Lấy được 50 liên kết công việc từ trang 163
# Lấy được 50 liên kết công việc từ trang 165
# Lấy được 50 liên kết công việc từ trang 164
# Lấy được 50 liên kết công việc từ trang 166
# Lỗi khi lấy liên kết từ trang 137: HTTPConnectionPool(host='localhost', port=54182): Read timed out. (read timeout=120)
# Lấy được 20 liên kết công việc từ trang 158
# Lấy được 50 liên kết công việc từ trang 167
# Lấy được 50 liên kết công việc từ trang 169
# Lấy được 50 liên kết công việc từ trang 168
# Lấy được 20 liên kết công việc từ trang 171
# Lấy được 50 liên kết công việc từ trang 170
# Lấy được 50 liên kết công việc từ trang 173
# Lấy được 50 liên kết công việc từ trang 176
# Lấy được 50 liên kết công việc từ trang 175
# Lấy được 50 liên kết công việc từ trang 174
# Lấy được 50 liên kết công việc từ trang 177
# Lấy được 50 liên kết công việc từ trang 172
# Lấy được 50 liên kết công việc từ trang 179
# Lấy được 50 liên kết công việc từ trang 178
# Lấy được 50 liên kết công việc từ trang 181
# Lấy được 50 liên kết công việc từ trang 182
# Lấy được 50 liên kết công việc từ trang 180
# Lấy được 50 liên kết công việc từ trang 184
# Lấy được 50 liên kết công việc từ trang 185
# Lấy được 50 liên kết công việc từ trang 183
# Lấy được 50 liên kết công việc từ trang 186
# Lấy được 50 liên kết công việc từ trang 187
# Lấy được 50 liên kết công việc từ trang 189
# Lấy được 20 liên kết công việc từ trang 196
# Lấy được 50 liên kết công việc từ trang 194
# Lấy được 50 liên kết công việc từ trang 192
# Lấy được 50 liên kết công việc từ trang 190
# Lấy được 50 liên kết công việc từ trang 191
# Lấy được 50 liên kết công việc từ trang 188
# Lấy được 50 liên kết công việc từ trang 195
# Lấy được 50 liên kết công việc từ trang 197
# Lấy được 50 liên kết công việc từ trang 193
# Lấy được 50 liên kết công việc từ trang 198
# Lấy được 20 liên kết công việc từ trang 200
# Lấy được 50 liên kết công việc từ trang 203
# Lấy được 50 liên kết công việc từ trang 204
# Lấy được 50 liên kết công việc từ trang 202
# Lấy được 50 liên kết công việc từ trang 201
# Lấy được 50 liên kết công việc từ trang 207
# Lấy được 50 liên kết công việc từ trang 209
# Lấy được 50 liên kết công việc từ trang 206
# Lấy được 50 liên kết công việc từ trang 199
# Lấy được 50 liên kết công việc từ trang 211
# Lấy được 50 liên kết công việc từ trang 213
# Lấy được 50 liên kết công việc từ trang 214
# Lấy được 50 liên kết công việc từ trang 212
# Lấy được 50 liên kết công việc từ trang 208
# Lấy được 50 liên kết công việc từ trang 210
# Lấy được 50 liên kết công việc từ trang 217
# Lấy được 50 liên kết công việc từ trang 216
# Lấy được 50 liên kết công việc từ trang 219
# Lấy được 20 liên kết công việc từ trang 225
# Lấy được 50 liên kết công việc từ trang 223
# Lấy được 50 liên kết công việc từ trang 224
# Lấy được 50 liên kết công việc từ trang 215
# Lấy được 50 liên kết công việc từ trang 222
# Lấy được 50 liên kết công việc từ trang 221
# Lỗi khi lấy liên kết từ trang 205: HTTPConnectionPool(host='localhost', port=59599): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 228
# Lấy được 50 liên kết công việc từ trang 230
# Lấy được 50 liên kết công việc từ trang 229
# Lấy được 50 liên kết công việc từ trang 227
# Lấy được 50 liên kết công việc từ trang 220
# Lấy được 50 liên kết công việc từ trang 233
# Lấy được 50 liên kết công việc từ trang 218
# Lấy được 50 liên kết công việc từ trang 231
# Lấy được 50 liên kết công việc từ trang 226
# Lấy được 20 liên kết công việc từ trang 237
# Lấy được 50 liên kết công việc từ trang 235
# Lấy được 50 liên kết công việc từ trang 236
# Lấy được 50 liên kết công việc từ trang 234
# Lấy được 50 liên kết công việc từ trang 240
# Lấy được 50 liên kết công việc từ trang 239
# Lấy được 50 liên kết công việc từ trang 238
# Lấy được 50 liên kết công việc từ trang 241
# Lấy được 50 liên kết công việc từ trang 242
# Lấy được 20 liên kết công việc từ trang 247
# Lấy được 50 liên kết công việc từ trang 246
# Lấy được 50 liên kết công việc từ trang 243
# Lấy được 50 liên kết công việc từ trang 244
# Lấy được 50 liên kết công việc từ trang 248
# Lấy được 50 liên kết công việc từ trang 250
# Lấy được 50 liên kết công việc từ trang 249
# Lấy được 50 liên kết công việc từ trang 251
# Lấy được 50 liên kết công việc từ trang 245
# Lỗi khi lấy liên kết từ trang 232: HTTPConnectionPool(host='localhost', port=61716): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 254
# Lấy được 50 liên kết công việc từ trang 255
# Lấy được 50 liên kết công việc từ trang 258
# Lấy được 50 liên kết công việc từ trang 260
# Lấy được 50 liên kết công việc từ trang 259
# Lấy được 50 liên kết công việc từ trang 257
# Lấy được 50 liên kết công việc từ trang 261
# Lấy được 20 liên kết công việc từ trang 262
# Lấy được 50 liên kết công việc từ trang 263
# Lấy được 50 liên kết công việc từ trang 265
# Lấy được 50 liên kết công việc từ trang 266
# Lấy được 50 liên kết công việc từ trang 268
# Lấy được 50 liên kết công việc từ trang 267
# Lấy được 50 liên kết công việc từ trang 269
# Lấy được 50 liên kết công việc từ trang 270
# Lấy được 50 liên kết công việc từ trang 256
# Lấy được 50 liên kết công việc từ trang 271
# Lấy được 50 liên kết công việc từ trang 272
# Lấy được 50 liên kết công việc từ trang 264
# Lấy được 50 liên kết công việc từ trang 275Lấy được 50 liên kết công việc từ trang 273
#
# Lấy được 50 liên kết công việc từ trang 277
# Lấy được 50 liên kết công việc từ trang 276
# Lấy được 50 liên kết công việc từ trang 278
# Lấy được 50 liên kết công việc từ trang 253
# Lấy được 50 liên kết công việc từ trang 279
# Lỗi khi lấy liên kết từ trang 252: HTTPConnectionPool(host='localhost', port=63462): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 280
# Lấy được 50 liên kết công việc từ trang 281
# Lấy được 50 liên kết công việc từ trang 282
# Lấy được 20 liên kết công việc từ trang 283
# Lấy được 50 liên kết công việc từ trang 286
# Lấy được 50 liên kết công việc từ trang 285
# Lấy được 50 liên kết công việc từ trang 284
# Lấy được 50 liên kết công việc từ trang 290
# Lấy được 50 liên kết công việc từ trang 289
# Lấy được 50 liên kết công việc từ trang 291
# Lấy được 50 liên kết công việc từ trang 288
# Lấy được 50 liên kết công việc từ trang 295
# Lấy được 50 liên kết công việc từ trang 294
# Lấy được 50 liên kết công việc từ trang 293
# Lấy được 50 liên kết công việc từ trang 287
# Lấy được 50 liên kết công việc từ trang 292
# Lấy được 50 liên kết công việc từ trang 296
# Lỗi khi lấy liên kết từ trang 274: HTTPConnectionPool(host='localhost', port=65035): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 297
# Lấy được 50 liên kết công việc từ trang 298
# Lấy được 50 liên kết công việc từ trang 299
# Lấy được 50 liên kết công việc từ trang 301
# Lấy được 50 liên kết công việc từ trang 303
# Lấy được 50 liên kết công việc từ trang 304
# Lấy được 50 liên kết công việc từ trang 302Lấy được 50 liên kết công việc từ trang 305
#
# Lấy được 50 liên kết công việc từ trang 307
# Lấy được 50 liên kết công việc từ trang 306
# Lấy được 50 liên kết công việc từ trang 300
# Lấy được 50 liên kết công việc từ trang 309
# Lấy được 50 liên kết công việc từ trang 310
# Lấy được 50 liên kết công việc từ trang 308
# Lấy được 50 liên kết công việc từ trang 311
# Lấy được 20 liên kết công việc từ trang 316
# Lấy được 50 liên kết công việc từ trang 317
# Lấy được 50 liên kết công việc từ trang 313
# Lấy được 50 liên kết công việc từ trang 319
# Lấy được 50 liên kết công việc từ trang 318
# Lấy được 50 liên kết công việc từ trang 312
# Lấy được 20 liên kết công việc từ trang 314
# Lấy được 50 liên kết công việc từ trang 320
# Lấy được 50 liên kết công việc từ trang 322
# Lấy được 50 liên kết công việc từ trang 323
# Lấy được 50 liên kết công việc từ trang 315
# Lấy được 50 liên kết công việc từ trang 324
# Lấy được 50 liên kết công việc từ trang 325
# Lấy được 50 liên kết công việc từ trang 326
# Lấy được 20 liên kết công việc từ trang 329
# Lấy được 50 liên kết công việc từ trang 321
# Lấy được 0 liên kết công việc từ trang 333
# Lấy được 50 liên kết công việc từ trang 328
# Lấy được 50 liên kết công việc từ trang 331
# Lấy được 50 liên kết công việc từ trang 330
# Lấy được 50 liên kết công việc từ trang 332
# Lấy được 50 liên kết công việc từ trang 327
# Lấy được 20 liên kết công việc từ trang 335
# Lấy được 50 liên kết công việc từ trang 336
# Lấy được 50 liên kết công việc từ trang 338
# Lấy được 50 liên kết công việc từ trang 339
# Lấy được 50 liên kết công việc từ trang 343
# Lấy được 50 liên kết công việc từ trang 337
# Lấy được 50 liên kết công việc từ trang 340
# Lấy được 50 liên kết công việc từ trang 342
# Lấy được 50 liên kết công việc từ trang 344
# Lấy được 50 liên kết công việc từ trang 345
# Lấy được 50 liên kết công việc từ trang 334
# Lấy được 50 liên kết công việc từ trang 341
# Lấy được 50 liên kết công việc từ trang 347
# Lấy được 50 liên kết công việc từ trang 346
# Lấy được 50 liên kết công việc từ trang 348
# Lấy được 50 liên kết công việc từ trang 352
# Lấy được 50 liên kết công việc từ trang 351
# Lấy được 50 liên kết công việc từ trang 353
# Lấy được 50 liên kết công việc từ trang 356
# Lấy được 50 liên kết công việc từ trang 349
# Lấy được 50 liên kết công việc từ trang 355
# Lấy được 50 liên kết công việc từ trang 357
# Lấy được 50 liên kết công việc từ trang 359
# Lấy được 50 liên kết công việc từ trang 358
# Lấy được 20 liên kết công việc từ trang 350
# Lấy được 50 liên kết công việc từ trang 361
# Lấy được 50 liên kết công việc từ trang 363
# Lấy được 50 liên kết công việc từ trang 360
# Lấy được 50 liên kết công việc từ trang 362
# Lấy được 50 liên kết công việc từ trang 364
# Lấy được 50 liên kết công việc từ trang 365
# Lấy được 50 liên kết công việc từ trang 367
# Lấy được 50 liên kết công việc từ trang 366
# Lấy được 50 liên kết công việc từ trang 370
# Lấy được 50 liên kết công việc từ trang 372
# Lấy được 50 liên kết công việc từ trang 368
# Lấy được 50 liên kết công việc từ trang 373
# Lấy được 50 liên kết công việc từ trang 369
# Lấy được 50 liên kết công việc từ trang 374
# Lấy được 50 liên kết công việc từ trang 371
# Lấy được 50 liên kết công việc từ trang 375
# Lỗi khi lấy liên kết từ trang 354: HTTPConnectionPool(host='localhost', port=55037): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 379
# Lấy được 50 liên kết công việc từ trang 382
# Lấy được 50 liên kết công việc từ trang 380
# Lấy được 50 liên kết công việc từ trang 377
# Lấy được 50 liên kết công việc từ trang 376
# Lấy được 50 liên kết công việc từ trang 381
# Lấy được 50 liên kết công việc từ trang 383
# Lấy được 50 liên kết công việc từ trang 384
# Lấy được 50 liên kết công việc từ trang 386
# Lấy được 50 liên kết công việc từ trang 385
# Lấy được 50 liên kết công việc từ trang 387
# Lấy được 50 liên kết công việc từ trang 390
# Lấy được 50 liên kết công việc từ trang 391
# Lấy được 50 liên kết công việc từ trang 393
# Lấy được 50 liên kết công việc từ trang 394
# Lấy được 50 liên kết công việc từ trang 389
# Lấy được 50 liên kết công việc từ trang 395
# Lấy được 20 liên kết công việc từ trang 388
# Lấy được 50 liên kết công việc từ trang 397
# Lấy được 20 liên kết công việc từ trang 399
# Lấy được 50 liên kết công việc từ trang 400
# Lấy được 50 liên kết công việc từ trang 396
# Lấy được 50 liên kết công việc từ trang 401
# Lấy được 50 liên kết công việc từ trang 403
# Lấy được 50 liên kết công việc từ trang 402
# Lỗi khi lấy liên kết từ trang 378: HTTPConnectionPool(host='localhost', port=57018): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 404
# Lấy được 50 liên kết công việc từ trang 405
# Lấy được 50 liên kết công việc từ trang 407
# Lấy được 50 liên kết công việc từ trang 408
# Lấy được 50 liên kết công việc từ trang 406
# Lấy được 50 liên kết công việc từ trang 409
# Lấy được 50 liên kết công việc từ trang 392
# Lấy được 50 liên kết công việc từ trang 410
# Lấy được 50 liên kết công việc từ trang 413
# Lấy được 50 liên kết công việc từ trang 412
# Lấy được 50 liên kết công việc từ trang 398
# Lấy được 20 liên kết công việc từ trang 414
# Lấy được 50 liên kết công việc từ trang 417
# Lấy được 50 liên kết công việc từ trang 415
# Lấy được 50 liên kết công việc từ trang 416
# Lấy được 50 liên kết công việc từ trang 418
# Lấy được 50 liên kết công việc từ trang 419
# Lấy được 50 liên kết công việc từ trang 420
# Lấy được 50 liên kết công việc từ trang 422
# Lấy được 50 liên kết công việc từ trang 423
# Lấy được 50 liên kết công việc từ trang 425
# Lấy được 50 liên kết công việc từ trang 424
# Lấy được 50 liên kết công việc từ trang 426
# Lấy được 50 liên kết công việc từ trang 429
# Lấy được 0 liên kết công việc từ trang 428
# Lấy được 0 liên kết công việc từ trang 427
# Lấy được 50 liên kết công việc từ trang 431
# Lấy được 50 liên kết công việc từ trang 430
# Lấy được 50 liên kết công việc từ trang 411
# Lấy được 50 liên kết công việc từ trang 433
# Lấy được 50 liên kết công việc từ trang 432
# Lấy được 20 liên kết công việc từ trang 437
# Lấy được 50 liên kết công việc từ trang 435
# Lấy được 50 liên kết công việc từ trang 436
# Lấy được 20 liên kết công việc từ trang 439
# Lấy được 50 liên kết công việc từ trang 438
# Lấy được 50 liên kết công việc từ trang 442Lấy được 50 liên kết công việc từ trang 441
#
# Lấy được 50 liên kết công việc từ trang 443
# Lấy được 50 liên kết công việc từ trang 440
# Lấy được 50 liên kết công việc từ trang 444
# Lấy được 50 liên kết công việc từ trang 447
# Lấy được 50 liên kết công việc từ trang 446
# Lấy được 50 liên kết công việc từ trang 421
# Lấy được 50 liên kết công việc từ trang 445
# Lấy được 50 liên kết công việc từ trang 448
# Lấy được 50 liên kết công việc từ trang 449
# Lấy được 50 liên kết công việc từ trang 450
# Lấy được 50 liên kết công việc từ trang 452
# Lấy được 50 liên kết công việc từ trang 451
# Lấy được 50 liên kết công việc từ trang 454
# Lấy được 50 liên kết công việc từ trang 456
# Lấy được 50 liên kết công việc từ trang 455
# Lấy được 50 liên kết công việc từ trang 453
# Lấy được 20 liên kết công việc từ trang 458
# Lấy được 50 liên kết công việc từ trang 457
# Lấy được 50 liên kết công việc từ trang 460
# Lỗi khi lấy liên kết từ trang 434: HTTPConnectionPool(host='localhost', port=61620): Read timed out. (read timeout=120)
# Lấy được 50 liên kết công việc từ trang 461
# Lấy được 50 liên kết công việc từ trang 462
# Lấy được 50 liên kết công việc từ trang 464
# Lấy được 50 liên kết công việc từ trang 465
# Lấy được 50 liên kết công việc từ trang 463
# Lấy được 50 liên kết công việc từ trang 466
# Lấy được 50 liên kết công việc từ trang 467
# Lấy được 50 liên kết công việc từ trang 469
# Lấy được 50 liên kết công việc từ trang 468
# Lấy được 50 liên kết công việc từ trang 471
# Lấy được 50 liên kết công việc từ trang 470
# Lấy được 50 liên kết công việc từ trang 459
# Lấy được 50 liên kết công việc từ trang 473
# Lấy được 50 liên kết công việc từ trang 474
# Lấy được 50 liên kết công việc từ trang 475
# Lấy được 50 liên kết công việc từ trang 476
# Lấy được 50 liên kết công việc từ trang 479
# Lấy được 50 liên kết công việc từ trang 480
# Lấy được 50 liên kết công việc từ trang 482
# Lấy được 50 liên kết công việc từ trang 472
# Lấy được 50 liên kết công việc từ trang 481
# Lấy được 50 liên kết công việc từ trang 484
# Lấy được 50 liên kết công việc từ trang 477
# Lấy được 50 liên kết công việc từ trang 487
# Lấy được 50 liên kết công việc từ trang 485
# Lấy được 50 liên kết công việc từ trang 489
# Lấy được 50 liên kết công việc từ trang 478
# Lấy được 50 liên kết công việc từ trang 488
# Lấy được 50 liên kết công việc từ trang 491
# Lấy được 50 liên kết công việc từ trang 486
# Lấy được 50 liên kết công việc từ trang 490
# Lấy được 50 liên kết công việc từ trang 483
# Lấy được 50 liên kết công việc từ trang 492
# Lấy được 50 liên kết công việc từ trang 494
# Lấy được 50 liên kết công việc từ trang 499
# Lấy được 50 liên kết công việc từ trang 496
# Lấy được 50 liên kết công việc từ trang 495
# Lấy được 50 liên kết công việc từ trang 497
# Lấy được 50 liên kết công việc từ trang 501
# Lấy được 50 liên kết công việc từ trang 500
# Lấy được 50 liên kết công việc từ trang 498
# Lấy được 50 liên kết công việc từ trang 502
# Lấy được 50 liên kết công việc từ trang 503
# Lấy được 50 liên kết công việc từ trang 505
# Lấy được 50 liên kết công việc từ trang 493
# Lấy được 50 liên kết công việc từ trang 504

# %% [markdown]
# ### Cào jobs từ URL trong file job_links

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

# Hàm để cào thông tin từ URL công ty (nếu có)
def fetch_company_details(company_url, headers):
    try:
        response = requests.get(company_url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Lấy tên công ty
        company_name = soup.select_one("h1.name").text.strip() if soup.select_one("h1.name") else "Not specified"

        # Lấy địa điểm công ty
        company_address = (
            soup.select_one("strong:contains('Địa điểm') + p").text.strip()
            if soup.select_one("strong:contains('Địa điểm') + p")
            else "Not specified"
        )

        # Lấy quy mô công ty (loại bỏ phần đầu "Quy mô công ty:")
        company_size_element = soup.select_one("li:has(.mdi-account-supervisor)")
        company_size = (
            company_size_element.text.replace("Qui mô công ty:", "").strip()
            if company_size_element else "Not specified"
        )

        # Lấy loại hình hoạt động (loại bỏ phần đầu "Loại hình hoạt động:")
        company_type_element = soup.select_one("li:has(.mdi-gavel)")
        company_type = (
            company_type_element.text.replace("Loại hình hoạt động:", "").strip()
            if company_type_element else "Not specified"
        )

        # Lấy đường dẫn website công ty
        company_website_element = soup.select_one("li:has(.mdi-link)")
        company_website = company_website_element.text.replace("Website: ", "").strip() if company_website_element else "Not specified"

        # Lấy số lượng người theo dõi
        follow_element = soup.select_one("#countFollowers")
        follower = follow_element.text if follow_element else "Not Found"

        # Lấy giới thiệu công ty
        company_intro_element = soup.select_one(".intro-section .main-text")
        company_intro = company_intro_element.text.strip() if company_intro_element else "Not specified"

        return {
            "Company Name": company_name,
            "Company Address": company_address,
            "Company Scale": company_size,
            "Company Type": company_type,
            "Company Website": company_website,
            "Follower": follower,
            "Company Introduction": company_intro
        }
    except requests.RequestException as e:
        print(f"Error fetching company details from '{company_url}': {e}")
        return {
            "Company Name": "Not specified",
            "Company Address": "Not specified",
            "Company Scale": "Not specified",
            "Company Type": "Not specified",
            "Company Website": "Not specified",
            "Follower": "Not specified",
            "Company Introduction": "Not specified"
        }

# Hàm cào dữ liệu từ một URL công việc
def crawl_single_job(job_url, headers):
    try:
        print(f"Crawling: {job_url}")
        response = requests.get(job_url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(random.uniform(1, 3))  # Chờ ngẫu nhiên để tránh bị chặn

        # Lấy tên công việc
        job_name = soup.select_one('h1.title').text.strip() if soup.select_one('h1.title') else "Not specified"

        # Lấy thông tin lương
        salary_info = (
            soup.select_one("strong:contains('Lương') + p").text.strip()
            if soup.select_one("strong:contains('Lương') + p")
            else "Not specified"
        )

        # Lấy địa điểm
        location_elements = soup.select('.map p a')
        locations = ', '.join([loc.text.strip() for loc in location_elements]) if location_elements else "Not specified"

        # Lấy các thông tin khác
        experience = (
            soup.select_one("strong:contains('Kinh nghiệm') + p").text.strip()
            if soup.select_one("strong:contains('Kinh nghiệm') + p")
            else "Not specified"
        )
        job_level = (
            soup.select_one("strong:contains('Cấp bậc') + p").text.strip()
            if soup.select_one("strong:contains('Cấp bậc') + p")
            else "Not specified"
        )
        deadline = (
            soup.select_one("strong:contains('Hết hạn nộp') + p").text.strip()
            if soup.select_one("strong:contains('Hết hạn nộp') + p")
            else "Not specified"
        )
        update_date = (
            soup.select_one("strong:contains('Ngày cập nhật') + p").text.strip()
            if soup.select_one("strong:contains('Ngày cập nhật') + p")
            else "Not specified"
        )
        employment_type = (
            soup.select_one("strong:contains('Hình thức') + p").text.strip()
            if soup.select_one("strong:contains('Hình thức') + p")
            else "Not specified"
        )

        # Lấy loại ngành nghề
        briefcase_element = soup.select_one("li:has(.mdi-briefcase)")
        list_briefcase = ", ".join([a.text for a in briefcase_element.find_all("a")]) if briefcase_element else "Not Found"

        # Lấy danh sách phúc lợi
        welfare_elements = soup.select("ul.welfare-list li")
        welfare_list = ', '.join([welfare.text.strip() for welfare in welfare_elements]) if welfare_elements else "Not specified"

        # Lấy phần "Mô tả Công việc"
        job_description_section = soup.select("h2:contains('Mô tả Công việc') ~ *")
        job_description_list = []
        for section in job_description_section:
            if section.name == "p" and section.text.strip():
                job_description_list.append(section.text.strip())
            elif section.name == "ul":
                description_items = section.find_all("li")
                job_description_list.extend([item.text.strip() for item in description_items if item.text.strip()])
        job_description = '\n'.join(job_description_list) if job_description_list else "Not specified"

        # Lấy phần "Yêu Cầu Công Việc"
        job_requirements_section = soup.select("h2:contains('Yêu Cầu Công Việc') ~ *")
        job_requirements_list = []
        for section in job_requirements_section:
            if section.name == "p" and section.text.strip():
                job_requirements_list.append(section.text.strip())
            elif section.name == "ul":
                requirements_items = section.find_all("li")
                job_requirements_list.extend([item.text.strip() for item in requirements_items if item.text.strip()])
        job_requirements = '\n'.join(job_requirements_list) if job_requirements_list else "Not specified"

        # Lấy nội dung của phần "Thông tin khác"
        other_info_section = soup.select_one("h3:contains('Thông tin khác') + div ul")
        other_info = '\n'.join([item.text.strip() for item in other_info_section.find_all("li")]) if other_info_section else "Not specified"

        # Lấy danh sách các Job Tags / Skills
        job_tags_elements = soup.select("div.job-tags ul li")
        job_tags = ', '.join([tag.text.strip() for tag in job_tags_elements]) if job_tags_elements else "Not specified"

        # Lấy URL công ty từ điều hướng
        company_url_element = soup.select_one("#tabs-job-company a")
        company_url = company_url_element['href'] if company_url_element else "Not Found"
        company_details = fetch_company_details(company_url, headers) if company_url != "Not Found" else {}

        # Tạo thông tin công việc
        job_information = {
            "Job Name": job_name,
            "Job Link": job_url,
            "Location": locations,
            "Update Date": update_date,
            "Deadline": deadline,
            "Experience": experience,
            "Job Level": job_level,
            "Industry": list_briefcase,
            "Employment Type": employment_type,
            "Welfare": welfare_list,
            "Job Description": job_description,
            "Job Requirements": job_requirements,
            "Other Information": other_info,
            "Job Tags": job_tags,
            "Company URL": company_url,
            **company_details,  # Thêm chi tiết công ty
            "Salary": salary_info
        }
        return job_information

    except requests.RequestException as e:
        print(f"Error fetching data from '{job_url}': {e}")
        return None

def crawl_job_information(job_urls):
    job_information_list = []
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    
    total_urls = len(job_urls)
    with ThreadPoolExecutor(max_workers=30) as executor:
        futures = [executor.submit(crawl_single_job, url, headers) for url in job_urls]
        for i, future in enumerate(as_completed(futures), 1):
            result = future.result()
            if result:
                job_information_list.append(result)
            # Print progress
            print(f"Crawled {i}/{total_urls} URLs")
    
    return pd.DataFrame(job_information_list)


# Đọc các link từ file txt
with open('job_links.txt', 'r', encoding='utf-8') as f:
    job_links_from_file = [line.strip() for line in f]

# Crawl job information based on collected job links
job_df = crawl_job_information(job_links_from_file)

# Print the DataFrame
job_df
# Out:
# Crawling: https://careerviet.vn/vi/tim-viec-lam/giam-sat-kho.35C274E6.html
# Crawling: https://careerviet.vn/vi/tim-viec-lam/ky-thuat-vien-quy-trinh.35C274CF.html
# Crawling: https://careerviet.vn/vi/tim-viec-lam/quan-ly-trang-trai-binh-duong.35C274C5.html
# Crawling: https://careerviet.vn/vi/tim-viec-lam/truong-phong-dau-tu-va-phat-trien-du-an-bat-dong-san.35C27462.html
# Crawling: https://careerviet.vn/vi/tim-viec-lam/nhan-vien-ho-tro-thanh-toan-khoan-vay-hien-truong-binh-duong.35C27465.html
# 3                            Not specified
# 4                      Nhân viên công nghệ
# ...                                    ...
# 23490                        Not specified
# 23491                        Not specified
# 23492                        Not specified
# 23493                        Not specified
# 23494                        Not specified
#
#                                                 Job Link       Location  \
# 0      https://careerviet.vn/vi/tim-viec-lam/chuyen-v...     Bình Dương
# 1      https://careerviet.vn/vi/tim-viec-lam/qa-staff...     Bình Dương
# 2      https://careerviet.vn/vi/tim-viec-lam/logistic...     Bình Dương
# 3      https://careerviet.vn/vi/tim-viec-lam/giam-sat...  Not specified
# 4      https://careerviet.vn/vi/tim-viec-lam/nhan-vie...     Bình Dương
# ...                                                  ...            ...
# 23490  https://careerviet.vn/vi/tim-viec-lam/chuyen-v...  Not specified
# 23491  https://careerviet.vn/vi/tim-viec-lam/chuyen-v...  Not specified
# 23492  https://careerviet.vn/vi/tim-viec-lam/product-...  Not specified
# 23493  https://careerviet.vn/vi/tim-viec-lam/nhan-vie...  Not specified
# 23494  https://careerviet.vn/vi/tim-viec-lam/chuyen-v...  Not specified
#
#          Update Date       Deadline  \
# 0         19/10/2024     17/11/2024
# 1         18/11/2024     15/12/2024
# 2         18/11/2024     19/12/2024
# 3      Not specified  Not specified
# 4         18/11/2024     31/12/2024
# ...              ...            ...
# 23490  Not specified  Not specified
# 23491  Not specified  Not specified
# 23492  Not specified  Not specified
# 23493  Not specified  Not specified
# 23494  Not specified  Not specified
#
#                                               Experience      Job Level  \
# 0      1 - 2 \r\n                                    ...      Nhân viên
# 1      Trên  1 \r\n                                  ...      Nhân viên
# 2      1 - 3 \r\n                                    ...      Nhân viên
# 3                                          Not specified  Not specified
# 4                                          Not specified      Nhân viên
# ...                                                  ...            ...
# 23490                                      Not specified  Not specified
# 23491                                      Not specified  Not specified
# 23492                                      Not specified  Not specified
# 23493                                      Not specified  Not specified
# 23494                                      Not specified  Not specified
#
#                                                 Industry  \
# 0      \r\n                                          ...
# 1      \r\n                                          ...
# 2      \r\n                                          ...
# 3                                              Not Found
# 4      \r\n                                          ...
# ...                                                  ...
# 23490                                          Not Found
# 23491                                          Not Found
# 23492                                          Not Found
# 23493                                          Not Found
# 23494                                          Not Found
#
#             Employment Type  \
# 0      Nhân viên chính thức
# 1      Nhân viên chính thức
# 2      Nhân viên chính thức
# 3             Not specified
# 4      Nhân viên chính thức
# ...                     ...
# 23490         Not specified
# 23491         Not specified
# 23492         Not specified
# 23493         Not specified
# 23494         Not specified
#
#                                                  Welfare  ...  \
# 0      Chế độ bảo hiểm, Du Lịch, Phụ cấp, Đồng phục, ...  ...
# 1      Chế độ bảo hiểm, Du Lịch, Chế độ thưởng, Chăm ...  ...
# 2      Laptop, Chế độ bảo hiểm, Du Lịch, Chế độ thưởn...  ...
# 3      Chế độ bảo hiểm, Phụ cấp, Đồng phục, Chế độ th...  ...
# 4      Chế độ bảo hiểm, Du Lịch, Phụ cấp, Đồng phục, ...  ...
# ...                                                  ...  ...
# 23490                                      Not specified  ...
# 23491                                      Not specified  ...
# 23492                                      Not specified  ...
# 23493                                      Not specified  ...
# 23494                                      Not specified  ...
#
#                                                 Job Tags  \
# 0      R D Staff, Trợ lý nghiên cứu và phát triển, Re...
# 1      qa staff, nhân viên kcs, nhân viên quản lý chấ...
# 2      chuyên viên phụ trách xuất nhập khẩu, nhân viê...
# 3                                          Not specified
# 4                                          Not specified
# ...                                                  ...
# 23490                                      Not specified
# 23491                                      Not specified
# 23492                                      Not specified
# 23493                                      Not specified
# 23494                                      Not specified
#
#                                              Company URL            Salary  \
# 0                                              Not Found  8 Tr - 11 Tr VND
# 1      https://careerviet.vn/vi/nha-tuyen-dung/cong-t...        Cạnh tranh
# 2      https://careerviet.vn/vi/nha-tuyen-dung/nnr-gl...     Trên  600 USD
# 3                                              Not Found     Not specified
# 4      https://careerviet.vn/vi/nha-tuyen-dung/cong-t...        Cạnh tranh
# ...                                                  ...               ...
# 23490                                          Not Found     Not specified
# 23491                                          Not Found     Not specified
# 23492                                          Not Found     Not specified
# 23493                                          Not Found     Not specified
# 23494                                          Not Found     Not specified
#
#                                             Company Name  \
# 0                                                    NaN
# 1                                   Công Ty Hansoll Vina
# 2               NNR GLOBAL LOGISTICS (VIET NAM) Co., LTD
# 3                                                    NaN
# 4      Công ty Cổ Phần Nhựa Thiếu Niên Tiền Phong Phí...
# ...                                                  ...
# 23490                                                NaN
# 23491                                                NaN
# 23492                                                NaN
# 23493                                                NaN
# 23494                                                NaN
#
#                                          Company Address Company Scale  \
# 0                                                    NaN           NaN
# 1                             Số 6,KCN Sóng Thần 1,Dĩ An         ~5000
# 2      05 Floor, SCSC Building, 30 Phan Thuc Duyen, W...       100-199
# 3                                                    NaN           NaN
# 4      LÔ C2, KCN ĐỒNG AN 2, P.HÒA PHÚ, TP THỦ DẦU MỘ...       500-999
# ...                                                  ...           ...
# 23490                                                NaN           NaN
# 23491                                                NaN           NaN
# 23492                                                NaN           NaN
# 23493                                                NaN           NaN
# 23494                                                NaN           NaN
#
#               Company Type            Company Website Follower  \
# 0                      NaN                        NaN      NaN
# 1      100% vốn nước ngoài            www.hansoll.com     298
# 2      Trách nhiệm hữu hạn  http://www.nnrglobal.com/     280
# 3                      NaN                        NaN      NaN
# 4                  Cổ phần   http://nhuatienphong.vn/   4.412
# ...                    ...                        ...      ...
# 23490                  NaN                        NaN      NaN
# 23491                  NaN                        NaN      NaN
# 23492                  NaN                        NaN      NaN
# 23493                  NaN                        NaN      NaN
# 23494                  NaN                        NaN      NaN
#
#                                     Company Introduction
# 0                                                    NaN
# 1      Công ty Hansoll Vina có vốn đầu tư 100% nước n...
# 2      NNR Global Logistics is the subsidiary of Nish...
# 3                                                    NaN
# 4      NHỰA TIỀN PHONG - ỐNG NHỰA SỐ 1 VIỆT NAMCông t...
# ...                                                  ...
# 23490                                                NaN
# 23491                                                NaN
# 23492                                                NaN
# 23493                                                NaN
# 23494                                                NaN
#
# [23495 rows x 23 columns]

# %%
job_df.to_csv('job_data.csv', index=False, encoding='utf-8-sig')
